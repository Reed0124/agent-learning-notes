# %%
# model
from rich import print as rprint
from dotenv import load_dotenv
load_dotenv(override=True)
from langchain.chat_models import init_chat_model
model = init_chat_model(
    model="deepseek-v4-flash", # 模型名称
)

# %% [markdown]
# ## 提示词模版

# %% [markdown]
# ### 1、ChatPromptTemplate

# %%
# 实例化
from langchain_core.prompts import ChatPromptTemplate

template = ChatPromptTemplate.from_messages(
    [
        ("system", "你是一个话少的助手"),
        ("human", "你叫什么名字"),
        ("ai", "我是{name}"),
        ("human", "{user_input}"),
    ]
)

# %% [markdown]
# #### 调用

# %%
# invoke调用
result = template.invoke({"user_input": "你叫什么名字来着", "name": "Alice"})
rprint(result)
rprint(type(result))
# Out:
# ChatPromptValue(
#     messages=[
#         SystemMessage(content='你是一个话少的助手', additional_kwargs={}, response_metadata={}),
#         HumanMessage(content='你叫什么名字', additional_kwargs={}, response_metadata={}),
#         AIMessage(
#             content='我是Alice',
#             additional_kwargs={},
#             response_metadata={},
#             tool_calls=[],
#             invalid_tool_calls=[]
#         ),
#         HumanMessage(content='你叫什么名字来着', additional_kwargs={}, response_metadata={})
#     ]
# )
# <class 'langchain_core.prompt_values.ChatPromptValue'>

# %%
# format调用
result = template.format(name="Alice", user_input="你叫什么名字来着")
rprint(result)
rprint(type(result))
# Out:
# System: 你是一个话少的助手
# Human: 你叫什么名字
# AI: 我是Alice
# Human: 你叫什么名字来着
# <class 'str'>

# %%
# format_messages调用
result = template.format_messages(name="Alice", user_input="你叫什么名字来着")
rprint(result)
rprint(type(result))
# Out:
# [
#     SystemMessage(content='你是一个话少的助手', additional_kwargs={}, response_metadata={}),
#     HumanMessage(content='你叫什么名字', additional_kwargs={}, response_metadata={}),
#     AIMessage(
#         content='我是Alice',
#         additional_kwargs={},
#         response_metadata={},
#         tool_calls=[],
#         invalid_tool_calls=[]
#     ),
#     HumanMessage(content='你叫什么名字来着', additional_kwargs={}, response_metadata={})
# ]
# <class 'list'>

# %% [markdown]
# ### model调用

# %%
response = model.invoke(result)
rprint(response)
rprint(type(response))
# Out:
# AIMessage(
#     content='我叫Alice，很高兴再次为你服务。',
#     additional_kwargs={
#         'refusal': None,
#         'reasoning_content':
# '（刚才我们明明刚说完我叫Alice，现在这位访客又问了一遍我的名字。看来他可能是个健忘的人，或者只是随口一问确认一下。
# 作为智能助手，我得保持耐心和友好。）\n\n（毕竟我的核心功能就是提供稳定可靠的服务，重复回答同样的问题也是工作的一部
# 分。既然他需要再确认一次，那我就用最简洁清晰的方式告诉他，避免任何可能造成混淆的表达。）\n\n（嗯，这样直截了当的回
# 答既符合他对话少的偏好，也不会让他觉得我在敷衍。反正我的名字又不会变，多重复几次也没关系。）'
#     },
#     response_metadata={
#         'token_usage': {
#             'completion_tokens': 128,
#             'prompt_tokens': 22,
#             'total_tokens': 150,
#             'completion_tokens_details': {
#                 'accepted_prediction_tokens': None,
#                 'audio_tokens': None,
#                 'reasoning_tokens': 119,
#                 'rejected_prediction_tokens': None
#             },
#             'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0},
#             'prompt_cache_hit_tokens': 0,
#             'prompt_cache_miss_tokens': 22
#         },
# ...
